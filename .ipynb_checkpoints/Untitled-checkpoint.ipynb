# %%
import requests
import pprint
import os
from bs4 import BeautifulSoup
from woocommerce import API
import pandas as pd

session = requests.Session()

print('GardenScraper v.2 by Django Claughan \nEdited by Fatih Canli' )

# Get login details form setup file
#thisFolder = os.path.dirname(os.path.abspath(__file__))
#setupFile = os.path.join(thisFolder, 'SETUP.txt')
f = open('SETUP.txt', "r")
details = f.read().split('\n') 

links = open('links.txt', "r")
link = links.read().split('\n') 

link = [x for x in link if x.find('https://www.gardners.com/Product/9') is 0]

print('Gardeners details')
print(details[4])
print(details[5])
print(details[6])
print('')
print('WooCommerce details')
print(details[9])
print(details[12])
print(details[15])
print(str(len(link))+' entries detected. Please press ENTER to proceed')

input()


# Initialise Woocommerce
wcapi = API(
    url = details[9],
    consumer_key = details[12],
    consumer_secret = details[15],
    version = 'wc/v3'
)

# Package Gardeners login details
payload = {
    'AccountNumber': details[4], 
    'UserName': details[5],
    'Password': details[6]
}

# Post the payload to the site to log in
data=[]
log=[]
s = session.post("https://www.gardners.com/Account/LogOn", data=payload)

print()

for url in link:
# Start loop to add products

  # Navigate to the next page and scrape the data
  page = session.get(url)

  soup = BeautifulSoup(page.content, 'html.parser')
  results = soup.find(id='body')
  # Get title
    
  searchBlock = results.find('div', class_='titleContributor')

  if searchBlock == None:
        print(url)
        print('No data retrieved.')
        print('\n\n')
        title='NO DATA'
        rrp='NO DATA'
        isbn='NO DATA'
        stock = 'NO DATA'
        img='NO DATA'
        description1='NO DATA'
  else: 
          title = searchBlock.find('h1')
          title = (title.text) 
            
          # Get ISBN
          searchBlock = results.find('li', class_='isbn')
          if searchBlock == None:
                isbn ='No ISBN'
          else:
                isbn = searchBlock.find_all('span')
                isbn = isbn[1].text
        
          # Get RRP
          searchBlock1 = results.find('div', class_='purchaseBlock')
          rrp = searchBlock1.find('span', class_='retailPrice')
          if rrp == None:
                print(url)
                rrp = searchBlock1.find('p', class_='rrp')
                if rrp == None:
                   print(isbn+' '+title+' '+' has no RRP ')
                   rrp1='NOT OK'
                else:
                   print(isbn+' '+title+' '+'is available.')
                   rrp = rrp.text
                   rrp = rrp.replace('RRP:', '')
                   rrp1='OK'
                   print(rrp)
                
          else: 
                  print(isbn+' '+title+' '+'is available.')
                  rrp = rrp.text
                  rrp1='OK'
                  print(rrp)
          # Get author(s)
          author = searchBlock.find_all('a')
          # Add author(s) to title
          n = 0
          for i in author:
              if n == 0:
                  title = title + ' by ' + i.text
              elif n == len(author) - 1:
                  title = title + ' and ' + i.text
              else:
                  title = title + ', ' + i.text
              n = n + 1
            

                
          # Get stock and change number for site
          searchBlock1 = results.find('div', class_='purchaseBlock')
          
          try:
              stock = searchBlock1.find(class_='availability')['data-copies']
          except:
              stock = 1
        
          if int(stock) > 4:
              stock = 1
          elif int(stock) > 0:
              stock = stock
          else:
              stock = 1
          print('Stock: '+str(stock))
          

          # Get description
          searchBlock = results.find('div', class_='description')
          if searchBlock == None:
                description = ''
                description1 = 'NOT OK'
                print('No description')
          else:
                description = searchBlock.find(class_='productDescription')
                description = description.text
                description1 = 'OK'
          # Get image url
          searchBlock = results.find(class_='imageContainer')

          if searchBlock.find('img')['src'] == "/Public/Images/noimage.jpg":
                imageSrc = 'https://www.narberthmuseum.co.uk/wp-content/uploads/woocommerce-placeholder.png'
                print('No image available')
                img='NOT OK'
          else:
                imageSrc = searchBlock.find('img')['data-zoom-image']
                imageSrc = 'https:' + imageSrc
                img='OK'

          

  log_data = {
      'url' : url,
      'isbn':isbn,
      'name':title,
      'regular_price':rrp,
      'image':imageSrc,
      'stock':stock,
      'description':description,
      'has_img':img,
      'has_desc':description1,
       'has_rrp':rrp1
       }
  log.append(log_data)
            # Package data to post to Woocommerce
                  new_data = {
            'images': [{
                "src": imageSrc
            },
                    ],
            'name': title,
            'regular_price': rrp,
            'short_description': description,
            'sku': isbn,
            'manage_stock': True,
            'stock_quantity': stock,
            'status': 'publish',
            'type': 'simple'
          }

        
          # Post data to the Woocommerce API
"""    
              print(wcapi.post('products',data).json())
  
              print('')


"""
print('Program finished. Press ENTER to close')

input()
# Out:
# <>:20: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:20: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-47-144df3fea03c>:20: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   link = [x for x in link if x.find('https://www.gardners.com/Product/9') is 0]
# GardenScraper v.2 by Django Claughan
# Edited by Fatih Canli
# Gardeners details
# NAR005
# NAR005
# AZSEF23T
#
# WooCommerce details
# https://narberthmuseum.co.uk
# ck_07e61955ca98c455c0c4040382a4921a8c7f8a44
# cs_609a44bdc0166e1a72061a3d666a9983a47181b8
# 81 entries detected. Please press ENTER to proceed
#
#
# https://www.gardners.com/Product/9780192782243
# 9780192782243 Oxford Treasury of Fairy Tales  has no RRP
# Stock: 1
# 1
#
#
#
# https://www.gardners.com/Product/9780439944014
# 9780439944014 Horrible Histories: Measly Middle Ages: Re-issue  has no RRP
# Stock: 1
# 2
#
#
#
# https://www.gardners.com/Product/9780744557787
# 9780744557787 Alice Through The Looking Glass  has no RRP
# Stock: 1
# 3
#
#
#
# https://www.gardners.com/Product/9781406317459
# 9781406317459 Classic Fairy Tales  has no RRP
# Stock: 1
# 4
#
#
#
# https://www.gardners.com/Product/9781407152578
# 9781407152578 Top 50 Kings and Queens  has no RRP
# Stock: 1
# 5
#
#
#
# https://www.gardners.com/Product/9781905264841
# 9781905264841 The Magical World of Milligan  has no RRP
# Stock: 1
# 6
#
#
#
# 9781905582860 Women of Wales is available.
# £7.99
# Stock: 1
# No description
# 7
#
#
#
# https://www.gardners.com/Product/9781907048005
# 9781907048005 Dear Mum : 13  has no RRP
# Stock: 1
# 8
#
#
#
# https://www.gardners.com/Product/9780008227913
# 9780008227913 i-SPY at the Museum : What Can You Spot? is available.
# £2.99
# Stock: 1
# 9
#
#
#
# https://www.gardners.com/Product/9781472903549
# 9781472903549 RSPB Spotlight: Puffins  has no RRP
# Stock: 1
# 10
#
#
#
# 9781910655535 Sky Chasers is available.
# £6.99
# Stock: 1
# 11
#
#
#
# https://www.gardners.com/Product/9781473654037
# 9781473654037 The End of Loneliness : The Dazzling International Bestseller  has no RRP
# Stock: 1
# 12
#
#
#
# https://www.gardners.com/Product/9780571333769
# 9780571333769 The Mabinogi  has no RRP
# Stock: 1
# 13
#
#
#
# https://www.gardners.com/Product/9780008327323
# 9780008327323 How to Fail : Everything I'Ve Ever Learned from Things Going Wrong  has no RRP
# Stock: 1
# 14
#
#
#
# https://www.gardners.com/Product/9781473656826
# 9781473656826 Incredible Journeys : Sunday Times Nature Book of the Year 2019  has no RRP
# Stock: 1
# 15
#
#
#
# https://www.gardners.com/Product/9780008285777
# 9780008285777 The Knife's Edge : The Heart and Mind of a Cardiac Surgeon is available.
# £14.99
# Stock: 1
# 16
#
#
#
# https://www.gardners.com/Product/9781925498523
# 9781925498523 The Trauma Cleaner  has no RRP
# Stock: 1
# No description
# 17
#
#
#
# https://www.gardners.com/Product/9781509821792
# 9781509821792 Everything in Its Place : First Loves and Last Tales  has no RRP
# Stock: 1
# 18
#
#
#
# https://www.gardners.com/Product/9780008291532
# 9780008291532 Semicolon : How a Misunderstood Punctuation Mark Can Improve Your Writing, Enrich Your Reading and Even Change Your Life is available.
# £10.00
# Stock: 1
# 19
#
#
#
# https://www.gardners.com/Product/9780857524904
# 9780857524904 Expectation : The most razor-sharp and heartbreaking novel of the year  has no RRP
# Stock: 1
# 20
#
#
#
# 9780749581855 Weird Museums is available.
# £12.99
# Stock: 1
# No description
# 21
#
#
#
# 9781407164724 Dear Santasaur (PB) is available.
# £6.99
# Stock: 1
# 22
#
#
#
# 9780008264093 Hubert Horatio: How to Raise Your Grown-Ups is available.
# £6.99
# Stock: 1
# 23
#
#
#
# 9781471172656 Shell is available.
# £8.99
# Stock: 1
# 24
#
#
#
# 9780857301307 A Friend Is A Gift You Give Yourself is available.
# £8.99
# Stock: 1
# No description
# 25
#
#
#
# https://www.gardners.com/Product/9781786897701
# 9781786897701 Rootbound : Rewilding a Life is available.
# £14.99
# Stock: 1
# 26
#
#
#
# https://www.gardners.com/Product/9781783442904
# 9781783442904 Not Now, Bernard is available.
# £6.99
# Stock: 1
# 27
#
#
#
# 9781609809379 The Rabbits' Rebellion is available.
# £9.99
# Stock: 1
# No description
# 28
#
#
#
# 9781907598166 Ten Poems from Wales is available.
# £4.95
# Stock: 1
# No description
# 29
#
#
#
# 9780198779858 Once Upon a Time : A Short History of Fairy Tale is available.
# £8.99
# Stock: 1
# 30
#
#
#
# 9780008200565 Head Kid is available.
# £6.99
# Stock: 1
# 31
#
#
#
# 9780753552650 Time and How to Spend It : The 7 Rules for Richer, Happier Days is available.
# £9.99
# Stock: 1
# 32
#
#
#
# 9780241379790 Stephen Biesty's Cross-Sections Castle is available.
# £14.99
# Stock: 1
# 33
#
#
#
# 9781786899378 Murmur is available.
# £8.99
# Stock: 1
# 34
#
#
#
# 9780857525185 The Forest of Wool and Steel : Winner of the Japan Booksellers' Award is available.
# £9.99
# Stock: 1
# 35
#
#
#
# 9781789291315 This Book Could Help : The Men's Head Space Manual - Techniques and Exercises for Living is available.
# £9.99
# Stock: 1
# 36
#
#
#
# 9781783784844 The Heavens is available.
# £12.99
# Stock: 1
# 37
#
#
#
# 9781529005547 Diary of a Somebody is available.
# £14.99
# Stock: 1
# 38
#
#
#
# https://www.gardners.com/Product/9781408867044
# 9781408867044 City of Girls : The Sunday Times Bestseller  has no RRP
# Stock: 1
# 39
#
#
#
# https://www.gardners.com/Product/9780141991740
# 9780141991740 No One Is Too Small to Make a Difference  has no RRP
# Stock: 1
# 40
#
#
#
# https://www.gardners.com/Product/9781847807199
# 9781847807199 ABC : See and say all the letters of the alphabet  has no RRP
# Stock: 1
# 41
#
#
#
# https://www.gardners.com/Product/9781405297769
# 9781405297769 Amelia Fang and the Bookworm Gang - World Book Day 2020 is available.
# £5.00
# Stock: 1
# 42
#
#
#
# https://www.gardners.com/Product/9781406395297
# 9781406395297 ALEX RIDER UNDERCOVER CLASSIFIED X50 PK  has no RRP
# Stock: 1
# No description
# 43
#
#
#
# https://www.gardners.com/Product/9781406394955
# 9781406394955 Alex Rider Undercover: Four Secret Files  has no RRP
# Stock: 1
# No image available
# 44
#
#
#
# https://www.gardners.com/Product/9780008375041
# 9780008375041 Bing's Splashy Story: World Book Day 2020  has no RRP
# Stock: 1
# 45
#
#
#
# https://www.gardners.com/Product/9781407199870
# 9781407199870 Dog Man: World Book Day 2020  has no RRP
# Stock: 1
# 46
#
#
#
# https://www.gardners.com/Product/9781838850753
# 9781838850753 Evie in the Jungle : World Book Day 2020  has no RRP
# Stock: 1
# 47
#
#
#
# https://www.gardners.com/Product/9781526619655
# 9781526619655 Kid Normal and the Loudest Library : World Book Day 2020  has no RRP
# Stock: 1
# 48
#
#
#
# 9781509852697 Adventures Of The Yorkshire Shepherdess is available.
# £8.99
# Stock: 1
# 49
#
#
#
# 9781916015920 Shine, Darling is available.
# £10.00
# Stock: 1
# No description
# 50
#
#
#
# 9781911547747 Real Life is available.
# £9.99
# Stock: 1
# No description
# 51
#
#
#
# 9781913111021 Mordew is available.
# £14.99
# Stock: 1
# No description
# 52
#
#
#
# 9781911293613 A Stranger in Paris : 1 is available.
# £8.99
# Stock: 1
# No image available
# 53
#
#
#
# 9781911584254 Dathlu'r Talwrn - Pigion ac Atgofion is available.
# £9.95
# Stock: 4
# No description
# 54
#
#
#
# https://www.gardners.com/Product/9781472628602
# 9781472628602 BOOKSHOP TOURS OF BRITIAN SIGNED EDITION  has no RRP
# Stock: 1
# No image available
# 55
#
#
#
# 9781472628589 HUNGRY SIGNED EDITION is available.
# £16.99
# Stock: 1
# No image available
# 56
#
#
#
# https://www.gardners.com/Product/978955212502
# No data retrieved.
#
#
#
# https://www.gardners.com/Product/9780007196586
# 9780007196586 Collins-Spurrell Express Welsh Dictionary  has no RRP
# Stock: 1
# 57
#
#
#
# https://www.gardners.com/Product/9780099264255
# 9780099264255 Redwall Family Tree  has no RRP
# Stock: 1
# 58
#
#
#
# 9780099558491 Castle : A History of the Buildings that Shaped Medieval Britain is available.
# £8.99
# Stock: 1
# 59
#
#
#
# https://www.gardners.com/Product/9780297607939
# 9780297607939 Dylan Thomas : A New Life  has no RRP
# Stock: 1
# 60
#
#
#
# https://www.gardners.com/Product/9780319242742
# 9780319242742 North Pembrokeshire / Gogledd Sir Benfro : OL 35 is available.
# £8.99
# Stock: 1
# 61
#
#
#
# https://www.gardners.com/Product/9780319263488
# 9780319263488 Wales & West Midlands : 6  has no RRP
# Stock: 1
# 62
#
#
#
# https://www.gardners.com/Product/9780540086566
# 9780540086566 Cardiff, Swansea and the Valleys  has no RRP
# Stock: 1
# 63
#
#
#
# https://www.gardners.com/Product/9780745955698
# 9780745955698 Wise Sayings of the Celts is available.
# £4.99
# Stock: 1
# 64
#
#
#
# https://www.gardners.com/Product/9780746052570
# 9780746052570 Who Were the Romans?  has no RRP
# Stock: 1
# 65
#
#
#
# https://www.gardners.com/Product/9780747557869
# 9780747557869 Aberystwyth Mon Amour is available.
# £7.99
# Stock: 1
# 66
#
#
#
# https://www.gardners.com/Product/9780747571605
# 9780747571605 The Red Judge  has no RRP
# Stock: 1
# 67
#
#
#
# https://www.gardners.com/Product/9780747803560
# 9780747803560 Discovering Local History : No. 290 is available.
# £10.99
# Stock: 1
# No image available
# 68
#
#
#
# https://www.gardners.com/Product/9780747804673
# 9780747804673 Ceramic Bygones : And Other Unusual Domestic Pottery : 383  has no RRP
# Stock: 1
# No image available
# 69
#
#
#
# https://www.gardners.com/Product/9780747805137
# 9780747805137 Bathroom Ceramics : 3 is available.
# £4.99
# Stock: 1
# No image available
# 70
# 9780747805892 Abbeys and Priories : 57 is available.
# £9.99
# Stock: 1
# 71
#
#
#
# https://www.gardners.com/Product/9780749567750
# 9780749567750 Northern England : No. 7  has no RRP
# Stock: 1
# 72
#
#
#
# 9780752423937 South Wales Collieries Volume 2 is available.
# £12.99
# Stock: 1
# 73
#
#
#
# 9780752440316 Gerald of Wales is available.
# £12.99
# Stock: 1
# 74
#
#
#
# 9780752442730 Airfields and Landing Grounds of Wales: South is available.
# £16.99
# Stock: 1
# 75
#
#
#
# 9780752449234 Brawdy : Stronghold in the West is available.
# £14.99
# Stock: 1
# 76
#
#
#
# 9780752471143 The Little Book of Great Britain is available.
# £9.99
# Stock: 1
# 77
#
#
#
# 9780752484785 History's Most Dangerous Jobs Miners : Miners is available.
# £12.99
# Stock: 1
# 78
#
#
#
# 9780752490052 Ancient Legends Retold: The Legend of Pryderi is available.
# £7.99
# Stock: 1
# 79
#
#
#
# 9780752497662 Brunel: pocket GIANTS is available.
# £6.99
# Stock: 1
# 80
#
#
#
# Program finished. Press ENTER to close
# ''

# %%
# Package data to post to Woocommerce
for i in range (len(df0)):  
    print(1)
    new_data = {
    'images': [{
        "src": df0['image'][i]
    },
            ],
    'name': df0['name'][i],
    'regular_price': df0['regular_price'][i],
    'short_description': df0['description'][i],
    'sku': df0['isbn'][i],
    'manage_stock': True,
    'stock_quantity': df0['stock'][i],
    'status': 'publish',
    'type': 'simple'
    }
    pprint(new_data)
# Out:
# 1
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-63-2bab91c13d7b> in <module>
#       4     new_data = {
#       5     'images': [{
# ----> 6         "src": df0['image'][i]
#       7     },
#       8             ],
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     880
#     881         elif key_is_scalar:
# --> 882             return self._get_value(key)
#     883
#     884         if is_hashable(key):
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#     987
#     988         # Similar to Index.get_value, but we do not fall back to positional
# --> 989         loc = self.index.get_loc(label)
#     990         return self.index._get_values_for_loc(self, loc, label)
#     991
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 0

# %%
import pprint

# %%
df = pd.DataFrame.from_dict(log)
mask=(df['has_desc']=='OK') & ( df['has_img']=='OK')  & ( df['has_rrp']=='OK')
mask1=(df['has_desc']=='NOT OK') | ( df['has_img']=='NOT OK') | ( df['has_rrp']=='NOT OK')
df0=df[mask]
df1=df[mask1]
df0.index+=1
df1.index+=1

writer = pd.ExcelWriter('output.xlsx', engine='xlsxwriter')
df0.to_excel(writer,sheet_name='Full Entries')
df1.to_excel(writer,sheet_name='Missing Entries')
writer.save()

# %%
df['name'][0]
# Out:
# 'Oxford Treasury of Fairy Tales'

# %%
df['has_desc']=='NOT OK'
# Out:
# 8     False
# 10    False
# 15    False
# 18    False
# 21    False
# 22    False
# 23    False
# 25    False
# 26    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# Name: has_desc, dtype: bool

# %%
# !jt -r
# Out:
# Reset css and font defaults in:
# C:\Users\Hello Rainbow\.jupyter\custom &
# C:\Users\Hello Rainbow\AppData\Roaming\jupyter\nbextensions

# %%
# !pyinstaller --onefile GardenScraper2.py
# Out:
# 72 INFO: PyInstaller: 4.1
# 72 INFO: Python: 3.8.5 (conda)
# 72 INFO: Platform: Windows-10-10.0.18362-SP0
# 73 INFO: wrote C:\Users\Hello Rainbow\Documents\gardener project\GardenScraper-main\source\GardenScraper2.spec
# 75 INFO: UPX is not available.
# 76 INFO: Extending PYTHONPATH with paths
# ['C:\\Users\\Hello Rainbow\\Documents\\gardener '
#  'project\\GardenScraper-main\\source',
#  'C:\\Users\\Hello Rainbow\\Documents\\gardener '
#  'project\\GardenScraper-main\\source']
# 115 INFO: checking Analysis
# 128 INFO: Building because C:\Users\Hello Rainbow\Documents\gardener project\GardenScraper-main\source\GardenScraper2.py changed
# 128 INFO: Initializing module dependency graph...
# 134 INFO: Caching module graph hooks...
# 146 INFO: Analyzing base_library.zip ...
# 4233 INFO: Processing pre-find module path hook distutils from 'c:\\users\\hello rainbow\\anaconda3\\lib\\site-packages\\PyInstaller\\hooks\\pre_find_module_path\\hook-distutils.py'.
# 4233 INFO: distutils: retargeting to non-venv dir 'c:\\users\\hello rainbow\\anaconda3\\lib'
# 7451 INFO: Caching module dependency graph...
# 7596 INFO: running Analysis Analysis-00.toc
# 7609 INFO: Adding Microsoft.Windows.Common-Controls to dependent assemblies of final executable
#   required by c:\users\hello rainbow\anaconda3\python.exe
# 7838 INFO: Analyzing C:\Users\Hello Rainbow\Documents\gardener project\GardenScraper-main\source\GardenScraper2.py
# C:\Users\Hello Rainbow\Documents\gardener project\GardenScraper-main\source\GardenScraper2.py:19: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   link = [x for x in link if x.find('https://www.gardners.com/') is 0]
# 8417 INFO: Processing pre-safe import module hook urllib3.packages.six.moves from 'c:\\users\\hello rainbow\\anaconda3\\lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module\\hook-urllib3.packages.six.moves.py'.
# 10467 INFO: Processing pre-safe import module hook six.moves from 'c:\\users\\hello rainbow\\anaconda3\\lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module\\hook-six.moves.py'.
# 14012 INFO: Processing module hooks...
# 14012 INFO: Loading module hook 'hook-bcrypt.py' from 'c:\\users\\hello rainbow\\anaconda3\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 14013 INFO: Loading module hook 'hook-certifi.py' from 'c:\\users\\hello rainbow\\anaconda3\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 14018 INFO: Loading module hook 'hook-cryptography.py' from 'c:\\users\\hello rainbow\\anaconda3\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 14243 INFO: Loading module hook 'hook-lxml.etree.py' from 'c:\\users\\hello rainbow\\anaconda3\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 14244 INFO: Loading module hook 'hook-difflib.py' from 'c:\\users\\hello rainbow\\anaconda3\\lib\\site-packages\\PyInstaller\\hooks'...
# 14245 INFO: Excluding import of doctest from module difflib
# 14245 INFO: Loading module hook 'hook-distutils.py' from 'c:\\users\\hello rainbow\\anaconda3\\lib\\site-packages\\PyInstaller\\hooks'...
# 14247 INFO: Loading module hook 'hook-distutils.util.py' from 'c:\\users\\hello rainbow\\anaconda3\\lib\\site-packages\\PyInstaller\\hooks'...
# 14248 INFO: Excluding import of lib2to3.refactor from module distutils.util
# 14248 INFO: Loading module hook 'hook-encodings.py' from 'c:\\users\\hello rainbow\\anaconda3\\lib\\site-packages\\PyInstaller\\hooks'...
# 14319 INFO: Loading module hook 'hook-heapq.py' from 'c:\\users\\hello rainbow\\anaconda3\\lib\\site-packages\\PyInstaller\\hooks'...
# 14321 INFO: Excluding import of doctest from module heapq
# 14321 INFO: Loading module hook 'hook-lib2to3.py' from 'c:\\users\\hello rainbow\\anaconda3\\lib\\site-packages\\PyInstaller\\hooks'...
# 14351 INFO: Loading module hook 'hook-multiprocessing.util.py' from 'c:\\users\\hello rainbow\\anaconda3\\lib\\site-packages\\PyInstaller\\hooks'...
# 14352 INFO: Excluding import of test.support from module multiprocessing.util
# 14352 INFO: Excluding import of test from module multiprocessing.util
# 14352 INFO: Loading module hook 'hook-pickle.py' from 'c:\\users\\hello rainbow\\anaconda3\\lib\\site-packages\\PyInstaller\\hooks'...
# 14354 INFO: Excluding import of argparse from module pickle
# 14354 INFO: Loading module hook 'hook-sysconfig.py' from 'c:\\users\\hello rainbow\\anaconda3\\lib\\site-packages\\PyInstaller\\hooks'...
# 14355 INFO: Loading module hook 'hook-xml.dom.domreg.py' from 'c:\\users\\hello rainbow\\anaconda3\\lib\\site-packages\\PyInstaller\\hooks'...
# 14355 INFO: Loading module hook 'hook-xml.etree.cElementTree.py' from 'c:\\users\\hello rainbow\\anaconda3\\lib\\site-packages\\PyInstaller\\hooks'...
# 14356 INFO: Loading module hook 'hook-xml.py' from 'c:\\users\\hello rainbow\\anaconda3\\lib\\site-packages\\PyInstaller\\hooks'...
# 14356 INFO: Loading module hook 'hook-_tkinter.py' from 'c:\\users\\hello rainbow\\anaconda3\\lib\\site-packages\\PyInstaller\\hooks'...
# 14493 INFO: checking Tree
# 14529 INFO: checking Tree
# 14609 INFO: checking Tree
# 14635 INFO: Looking for ctypes DLLs
# 14672 INFO: Analyzing run-time hooks ...
# 14676 INFO: Including run-time hook 'c:\\users\\hello rainbow\\anaconda3\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_multiprocessing.py'
# 14679 INFO: Including run-time hook 'c:\\users\\hello rainbow\\anaconda3\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_win32api.py'
# 14690 INFO: Including run-time hook 'c:\\users\\hello rainbow\\anaconda3\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\rthooks\\pyi_rth_certifi.py'
# 14698 INFO: Looking for dynamic libraries
# 14998 INFO: Looking for eggs
# 14998 INFO: Using Python library c:\users\hello rainbow\anaconda3\python38.dll
# 14998 INFO: Found binding redirects:
# []
# 15002 INFO: Warnings written to C:\Users\Hello Rainbow\Documents\gardener project\GardenScraper-main\source\build\GardenScraper2\warn-GardenScraper2.txt
# 15069 INFO: Graph cross-reference written to C:\Users\Hello Rainbow\Documents\gardener project\GardenScraper-main\source\build\GardenScraper2\xref-GardenScraper2.html
# 15085 INFO: checking PYZ
# 15095 INFO: Building because toc changed
# 15095 INFO: Building PYZ (ZlibArchive) C:\Users\Hello Rainbow\Documents\gardener project\GardenScraper-main\source\build\GardenScraper2\PYZ-00.pyz
# 15957 INFO: Building PYZ (ZlibArchive) C:\Users\Hello Rainbow\Documents\gardener project\GardenScraper-main\source\build\GardenScraper2\PYZ-00.pyz completed successfully.
# 15972 INFO: checking PKG
# 15978 INFO: Building because toc changed
# 15978 INFO: Building PKG (CArchive) PKG-00.pkg
# C:\Users\Hello Rainbow\Documents\gardener project\GardenScraper-main\source\GardenScraper2.py:19: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   link = [x for x in link if x.find('https://www.gardners.com/') is 0]
# 18353 INFO: Building PKG (CArchive) PKG-00.pkg completed successfully.
# 18357 INFO: Bootloader c:\users\hello rainbow\anaconda3\lib\site-packages\PyInstaller\bootloader\Windows-64bit\run.exe
# 18357 INFO: checking EXE
# 18365 INFO: Rebuilding EXE-00.toc because GardenScraper2.exe missing
# 18365 INFO: Building EXE from EXE-00.toc
# 18365 INFO: Appending archive to EXE C:\Users\Hello Rainbow\Documents\gardener project\GardenScraper-main\source\dist\GardenScraper2.exe
# 18379 INFO: Building EXE from EXE-00.toc completed successfully.
